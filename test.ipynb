# %%
import xarray as xr

# %%
x_train= xr.open_zarr(r'C:\Users\RaffaeleScarano\Gmatics\DAMAS\yandex-shifts-weather\data\yandex-shifts\weather\x_train_cube.zarr')
y_train= xr.open_zarr(r'C:\Users\RaffaeleScarano\Gmatics\DAMAS\yandex-shifts-weather\data\yandex-shifts\weather\y_train_cube.zarr')

# %%
x_train
# Out:
# <xarray.Dataset>
# Dimensions:                    (time: 17, lat: 106, lon: 133)
# Coordinates:
#   * lat                        (lat) float64 34.64 34.62 34.6 ... 32.57 32.55
#   * lon                        (lon) float64 10.2 10.22 10.24 ... 12.82 12.84
#   * time                       (time) datetime64[ns] 2018-12-01 ... 2018-12-0...
# Data variables: (12/20)
#     10_metre_u_wind_component  (time, lat, lon) float64 dask.array<chunksize=(1, 106, 133), meta=np.ndarray>
#     10_metre_v_wind_component  (time, lat, lon) float64 dask.array<chunksize=(1, 106, 133), meta=np.ndarray>
#     2_metre_temperature        (time, lat, lon) float64 dask.array<chunksize=(1, 106, 133), meta=np.ndarray>
#     evaporation                (time, lat, lon) float64 dask.array<chunksize=(1, 106, 133), meta=np.ndarray>
#     latent_heat_flux           (time, lat, lon) float64 dask.array<chunksize=(1, 106, 133), meta=np.ndarray>
# ...

# %%
y_train
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 17, lat: 106, lon: 133)
# Coordinates:
#   * lat      (lat) float64 34.64 34.62 34.6 34.58 ... 32.61 32.59 32.57 32.55
#   * lon      (lon) float64 10.2 10.22 10.24 10.26 ... 12.78 12.8 12.82 12.84
#   * time     (time) datetime64[ns] 2018-12-01 ... 2018-12-01T16:00:00
# Data variables:
#     Eta      (time, lat, lon) float32 dask.array<chunksize=(1, 106, 133), meta=np.ndarray>
#     S        (time, lat, lon) float32 dask.array<chunksize=(1, 106, 133), meta=np.ndarray>
#     T        (time, lat, lon) float32 dask.array<chunksize=(1, 106, 133), meta=np.ndarray>
#     U        (time, lat, lon) float32 dask.array<chunksize=(1, 106, 133), meta=np.ndarray>
#     V        (time, lat, lon) float32 dask.array<chunksize=(1, 106, 133), meta=np.ndarray>
# Attributes:
#     Conventions:           CF-1.7
#     date_modified:         2022-01-10T13:23:09.702196
#     geospatial_lat_max:    47.287626244808855
#     geospatial_lat_min:    30.1999279
# ...

# %%
x_df= x_train.to_dataframe()
y_df= y_train.to_dataframe()

# %%
x_df.dropna()
x_df
# Out:
#                                          10_metre_u_wind_component  \
# time                lat       lon
# 2018-12-01 00:00:00 34.641532 10.203631                        NaN
#                               10.223593                        NaN
#                               10.243556                        NaN
#                               10.263518                        NaN
#                               10.283480                        NaN
# ...                                                            ...
# 2018-12-01 16:00:00 32.545494 12.758801                        NaN
#                               12.778763                        NaN
#                               12.798726                        NaN
#                               12.818688                        NaN
#                               12.838650                        NaN
#
#                                          10_metre_v_wind_component  \
# time                lat       lon
# ...

# %%
y_df.dropna()
y_df
# Out:
#                                          Eta   S   T   U   V
# time                lat       lon
# 2018-12-01 00:00:00 34.641532 10.203631  NaN NaN NaN NaN NaN
#                               10.223593  NaN NaN NaN NaN NaN
#                               10.243556  NaN NaN NaN NaN NaN
#                               10.263518  NaN NaN NaN NaN NaN
#                               10.283480  NaN NaN NaN NaN NaN
# ...                                      ...  ..  ..  ..  ..
# 2018-12-01 16:00:00 32.545494 12.758801  NaN NaN NaN NaN NaN
#                               12.778763  NaN NaN NaN NaN NaN
#                               12.798726  NaN NaN NaN NaN NaN
#                               12.818688  NaN NaN NaN NaN NaN
#                               12.838650  NaN NaN NaN NaN NaN
#
# [239666 rows x 5 columns]
